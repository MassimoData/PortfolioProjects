# %%
# Import Libraries
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

pd.options.mode.chained_assignment = None

# Import Data

df = pd.read_csv('D:\Datasets\MovieIndustry\movies.csv')

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# Checking to see if data is complete then filling in missing values
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, pct_missing))
    df=df.fillna(0)
# Out:
# name - 0.0%
# rating - 0.0%
# genre - 0.0%
# year - 0.0%
# released - 0.0%
# score - 0.0%
# votes - 0.0%
# director - 0.0%
# writer - 0.0%
# star - 0.0%
# country - 0.0%
# budget - 0.0%
# gross - 0.0%
# company - 0.0%
# runtime - 0.0%

# %%
# Looking at data types
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# Making the Budget & Gross look nicer
df['budget'] = df['budget'].astype('int64')
df['gross'] = df['gross'].astype('int64')
df['company']

# %%
pd.set_option('display.max_rows', 5)
df.sort_values(by=['gross'], inplace=False, ascending=False)
# Out:
#                    name rating   genre  year  \
# 5445             Avatar  PG-13  Action  2009
# 7445  Avengers: Endgame  PG-13  Action  2019
# ...                 ...    ...     ...   ...
# 7666       It's Just Us    NaN   Drama  2020
# 7667          Tee em el    NaN  Horror  2020
#
#                                released  score      votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000.0  Anthony Russo
# ...                                 ...    ...        ...            ...
# 7666    October 1, 2020 (United States)    NaN        NaN  James Randall
# 7667    August 19, 2020 (United States)    5.7        7.0   Pereko Mosia
#
#                   writer               star        country       budget  \
# 5445       James Cameron    Sam Worthington  United States  237000000.0
# 7445  Christopher Markus  Robert Downey Jr.  United States  356000000.0
# ...

# %%
pd.set_option('display.max_rows', 200)

# %%
#Removing duplicates
df.drop_duplicates()
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life      0      Drama  2020
# 7664                                     Dream Round      0     Comedy  2020
# 7665                                   Saving Mbango      0      Drama  2020
# 7666                                    It's Just Us      0      Drama  2020
# 7667                                       Tee em el      0     Horror  2020
#
# ...

# %%
# Scatter plot budget vs gross

plt.scatter(x=df['budget'], y=df['gross'])
plt.title('Budget vs Gross Earnings')
plt.xlabel('Film Budget')
plt.ylabel('Gross Earnings')
plt.show()

# %%
# Plot of budget vs gross using seaborn (includes r)

sns.regplot(x='budget', y='gross', data=df, scatter_kws = {"color":"red"}, line_kws={"color":"blue"})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %%
#Looking at correlations of only numerical values
#There is a high correlation between budget and gross
df.corr(method = 'pearson')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.092616  0.222427  0.309212  0.261900  0.116358
# score    0.092616  1.000000  0.407101  0.056863  0.186012  0.394564
# votes    0.222427  0.407101  1.000000  0.486931  0.632870  0.306984
# budget   0.309212  0.056863  0.486931  1.000000  0.750157  0.268372
# gross    0.261900  0.186012  0.632870  0.750157  1.000000  0.244339
# runtime  0.116358  0.394564  0.306984  0.268372  0.244339  1.000000

# %%
#Visualization of the Pearson correlation matrix
correlation_matrix = df.corr(method = 'pearson')
sns.heatmap(correlation_matrix, annot = True)
plt.title('Correlation Matrix')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
plt.show()

# %%
#Convert company to a numeric value so that it can be used for correlation
df_convertnumber = df

for col_name in df_convertnumber.columns:
    if(df_convertnumber[col_name].dtype =='object'):
        df_convertnumber[col_name] = df_convertnumber[col_name].astype('category')
        df_convertnumber[col_name] = df_convertnumber[col_name].cat.codes

df_convertnumber
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 0     6587       7      6  1980      1706    8.4   927000.0      2589    4015
# 1     5573       7      1  1980      1493    5.8    65000.0      2269    1633
# 2     5142       5      0  1980      1772    8.7  1200000.0      1111    2568
# 3      286       5      4  1980      1493    7.7   221000.0      1301    2001
# 4     1027       7      4  1980      1544    7.3   108000.0      1054     522
# ...    ...     ...    ...   ...       ...    ...        ...       ...     ...
# 7663  3705       0      6  2020      2965    3.1       18.0      1500    2290
# 7664  1678       0      4  2020      1108    4.7       36.0       774    2615
# 7665  4717       0      6  2020       194    5.7       29.0      2061    2684
# 7666  2843       0      6  2020      2818    0.0        0.0      1184    1825
# 7667  5394       0     10  2020       392    5.7        7.0      2165    3345
#
# ...

# %%
#correlation matrix with all data values

correlation_matrix = df_convertnumber.corr(method = 'pearson')
sns.heatmap(correlation_matrix, annot = True)
plt.title('Correlation Matrix')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
plt.show()

# %%
df_convertnumber.corr()
# Out:
#                  name    rating     genre      year  released     score  \
# name         1.000000 -0.008069  0.016355  0.011453 -0.011311  0.016377
# rating      -0.008069  1.000000  0.072423  0.008779  0.016613  0.006192
# genre        0.016355  0.072423  1.000000 -0.081261  0.029822  0.027384
# year         0.011453  0.008779 -0.081261  1.000000 -0.000695  0.092616
# released    -0.011311  0.016613  0.029822 -0.000695  1.000000  0.039814
# score        0.016377  0.006192  0.027384  0.092616  0.039814  1.000000
# votes        0.013038  0.033743 -0.145296  0.222427  0.015878  0.407101
# director     0.009079  0.019483 -0.015258 -0.020795 -0.001478  0.010568
# writer       0.009081 -0.005921  0.006567 -0.008656 -0.002404  0.022098
# star         0.006472  0.013405 -0.005477 -0.027242  0.015777 -0.000026
# country     -0.010737  0.081244 -0.037615 -0.070938 -0.020427 -0.133346
# budget       0.020548 -0.081939 -0.334021  0.309212  0.009145  0.056863
# ...

# %%
correlation_matrix_convert = df_convertnumber.corr()
corr_pairs = correlation_matrix_convert.unstack()

# %%
sorted_pairs = corr_pairs.sort_values()

# %%
#only showing highly correlated variables
high_corr = sorted_pairs[(sorted_pairs > .5) & (sorted_pairs < .98)]
high_corr
# Out:
# gross   votes     0.632870
# votes   gross     0.632870
# budget  gross     0.750157
# gross   budget    0.750157
# dtype: float64
